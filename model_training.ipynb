# %%
import pandas as pd
import numpy as np
from pathlib import Path
import gc
from sklearn.impute import KNNImputer

def standardize_column_names(columns):
    """
    Uniformiza os nomes das colunas removendo a letra do meio entre os underscores.
    """
    standardized = []
    for col in columns:
        parts = col.split('_')
        if len(parts) == 3 and len(parts[1]) == 1:  # Se tem formato XXX_Y_ZZZ
            standardized.append(f"{parts[0]}_{parts[2]}")
        else:
            standardized.append(col)
    return standardized

def load_and_preprocess_nhanes_2013_2014(file_path):
    """
    Carrega e pré-processa os dados do NHANES 2013-2014
    """
    try:
        # Carregar dados
        df = pd.read_csv(file_path)
        print(f"Dados 2013-2014 carregados. Shape inicial: {df.shape}")
        
        # Remover colunas específicas não desejadas
        columns_to_remove = [
            'DXXFEM_H_DXXINBMD', 'DXXSPN_H_DXXOSBMD.1', 'DXXFEM_H_DXXWDBMD',
            'DXXSPN_H_DXXL1BMD', 'DXXFEM_H_DXXTRBMD', 'DXXSPN_H_DXXL2BMD',
            'DXXSPN_H_DXXL3BMD', 'DXXSPN_H_DXXL4BMD'
        ]
        df = df.drop(columns=columns_to_remove, errors='ignore')
        
        # Uniformizar nomes das colunas
        df.columns = standardize_column_names(df.columns)
        
        # Remover colunas duplicadas
        df = df.loc[:, ~df.columns.duplicated()]
        print(f"Shape após processamento: {df.shape}")
        
        return df
        
    except Exception as e:
        print(f"Erro ao carregar dados 2013-2014: {str(e)}")
        return None

def load_nhanes_cycle(directory_path, reference_columns):
    """
    Carrega e processa dados de um ciclo do NHANES
    """
    directory = Path(directory_path)
    if not directory.exists():
        print(f"Diretório {directory} não existe.")
        return None
    
    try:
        dataframes = []
        
        # Primeira passagem: carregar todos os arquivos XPT
        for file_path in directory.glob('*.XPT'):
            try:
                df = pd.read_sas(file_path, format='xport')
                file_name = file_path.stem
                
                if 'SEQN' in df.columns:
                    # Renomear colunas com prefixo do nome do arquivo
                    rename_dict = {col: f"{file_name}_{col}" if col != 'SEQN' else col 
                                 for col in df.columns}
                    df = df.rename(columns=rename_dict)
                    
                    # Garantir que SEQN seja único
                    df = df.sort_values('SEQN').groupby('SEQN').first().reset_index()
                    
                    dataframes.append(df)
                    print(f"Arquivo válido: {file_name}, Shape: {df.shape}")
                    
            except Exception as e:
                print(f"Erro ao ler {file_path}: {str(e)}")
        
        if not dataframes:
            print("Nenhum arquivo XPT válido encontrado.")
            return None
            
        # Realizar o merge de todos os DataFrames
        print("\nIniciando processo de merge...")
        df_merged = dataframes[0]
        for i, df in enumerate(dataframes[1:], 1):
            print(f"\nMergindo DataFrame {i} de {len(dataframes)-1}")
            df_merged = pd.merge(df_merged, df, on='SEQN', how='outer')
            gc.collect()
        
        # Limpar memória
        del dataframes
        gc.collect()
        
        # Uniformizar nomes das colunas
        df_merged.columns = standardize_column_names(df_merged.columns)
        
        # Selecionar apenas as colunas de interesse
        common_columns = set(df_merged.columns) & set(reference_columns)
        df_merged = df_merged[list(common_columns)]
        
        # Remover linhas com dados faltantes nos valores de BMD
        bmd_columns = ['DXXFEM_DXXNKBMD', 'DXXFEM_DXXOFBMD', 'DXXSPN_DXXOSBMD']
        df_merged = df_merged.dropna(subset=bmd_columns, how='all')
        
        # Filtrar para idade >= 40 anos
        print(f"\nShape antes do filtro de idade: {df_merged.shape}")
        df_merged = df_merged[df_merged['DEMO_RIDAGEYR'] >= 50]
        print(f"Shape após filtro de idade (>=50 anos): {df_merged.shape}")
        
        print(f"\nDistribuição de idade após filtro:")
        print(df_merged['DEMO_RIDAGEYR'].describe())
        
        print(f"\nShape final após processamento: {df_merged.shape}")
        return df_merged
        
    except Exception as e:
        print(f"Erro ao processar ciclo NHANES: {str(e)}")
        return None

def calculate_t_scores(df):
    """
    Calcula T-scores para diferentes regiões ósseas usando valores de referência atualizados
    """
    # Definir valores de referência atualizados
    reference_values = {
        'fn': {  # Femoral Neck
            'white': {'female': (0.875, 0.126), 'male': (0.929, 0.133)},
            'black': {'female': (0.981, 0.156), 'male': (1.037, 0.160)},
            'hispanic': {'female': (0.869, 0.114), 'male': (0.968, 0.131)}
        },
        'tf': {  # Total Femur
            'white': {'female': (0.960, 0.123), 'male': (1.048, 0.136)},
            'black': {'female': (1.044, 0.136), 'male': (1.148, 0.164)},
            'hispanic': {'female': (0.954, 0.120), 'male': (1.083, 0.136)}
        },
        'sp': {  # Spine
            'white': {'female': (1.046, 0.110), 'male': (1.047, 0.118)},
            'black': {'female': (1.118, 0.129), 'male': (1.101, 0.120)},
            'hispanic': {'female': (1.019, 0.108), 'male': (1.041, 0.112)}
        }
    }
    
    def get_reference_values(gender, race, site):
        if race in [1, 2]:  # Hispanic
            ethnicity = 'hispanic'
        elif race == 4:  # Black
            ethnicity = 'black'
        else:  # White and others
            ethnicity = 'white'
        
        gender_str = 'female' if gender == 2 else 'male'
        return reference_values[site][ethnicity][gender_str]
    
    def calculate_single_t_score(bmd, mean, sd):
        return (bmd - mean) / sd if pd.notnull(bmd) else np.nan
    
    # Calcular T-scores para cada região
    sites = {
        'fn': 'DXXFEM_DXXNKBMD',
        'tf': 'DXXFEM_DXXOFBMD',
        'sp': 'DXXSPN_DXXOSBMD'
    }
    
    for site, column in sites.items():
        df[f'T_score_{site}'] = df.apply(
            lambda row: calculate_single_t_score(
                row[column],
                *get_reference_values(row['DEMO_RIAGENDR'], row['DEMO_RIDRETH1'], site)
            ),
            axis=1
        )
    
    print(f"T-scores calculados para {df.shape[0]} registros")
    return df

def create_target_variable(df):
    """ 
    Cria variável target baseada nos T-scores e outros critérios:
    - T-score ≤ -2.5 em qualquer sítio
    - Percentis calculados separadamente para homens e mulheres
    """
    try:
        # Separar por género
        df_male = df[df['DEMO_RIAGENDR'] == 1].copy()
        df_female = df[df['DEMO_RIAGENDR'] == 2].copy()
        
        # Função para calcular percentis
        def calculate_percentiles(data):
            data["BMI"]=data['BMX_BMXWT']/(data['BMX_BMXHT']*data['BMX_BMXHT'])
            data['BMI_percentil'] = pd.qcut(data['BMI'], q=15, labels=False, duplicates='drop')
            data['RIDAGEYR_percentil'] = pd.qcut(data['DEMO_RIDAGEYR'], q=15, labels=False, duplicates='drop')
            data['BMXWT_percentil'] = pd.qcut(data['BMX_BMXWT'], q=15, labels=False)
            data['BMXHT_percentil'] = pd.qcut(data['BMX_BMXHT'], q=15, labels=False)
            data['BMXARMC_percentil'] = pd.qcut(data['BMX_BMXARMC'], q=15, labels=False)
            return data
        
        # Calcular percentis separadamente
        df_male = calculate_percentiles(df_male)
        df_female = calculate_percentiles(df_female)
        
        # Recombinar os dados
        df = pd.concat([df_male, df_female])
        
        def categorize_bone_health(row):
            t_scores = [row[f'T_score_{site}'] for site in ['fn', 'tf', 'sp']]
            t_scores = [score for score in t_scores if pd.notnull(score)]
            
            if not t_scores:
                return np.nan
            
            min_t_score = min(t_scores)
            
            # Inicializa o critério antropométrico como False
            anthropometric_criteria = False
            
            # Critério de peso aplicado para todos
            if row.get('BMXWT_percentil') == 0 or row.get('BMXARMC_percentil') == 0:
                anthropometric_criteria = True
            
            # Critério de idade aplicado apenas para mulheres
            if row.get('DEMO_RIAGENDR') == 2 and row.get('RIDAGEYR_percentil') == 13:
                anthropometric_criteria = True

            if min_t_score <= -2.5 or anthropometric_criteria:
                return 1
            return 0

        # Criar variável target
        df['target'] = df.apply(categorize_bone_health, axis=1)
        
        # Análise dos critérios de classificação
        def analyze_classification_criteria(df):
            total_valid = df['target'].notna().sum()
            osteo = (df['target'] == 1).sum()
            
            criteria_counts = {
                'T-score ≤ -2.5': sum((df[[f'T_score_{site}' for site in ['fn', 'tf', 'sp']]].min(axis=1) <= -2.5) & (df['target'] == 1)),
                'All T-scores ≤ -1.0': sum(df[[f'T_score_{site}' for site in ['fn', 'tf', 'sp']]].apply(lambda x: all(score <= -1.0 for score in x), axis=1) & (df['target'] == 1)),
                'Age (highest percentile)': sum((df['RIDAGEYR_percentil'] == 19) & (df['target'] == 1)),
                'Weight (lowest percentile)': sum((df['BMXWT_percentil'] == 0) & (df['target'] == 1)),
                'Arm circumference (lowest percentile)': sum((df['BMXARMC_percentil'] == 0) & (df['target'] == 1))
            }
            
            print("\nCritérios de classificação para casos positivos:")
            for criterion, count in criteria_counts.items():
                print(f"{criterion}: {count} casos ({count/osteo*100:.1f}% dos positivos)")
        
        # Análises separadas por género
        for gender, label in [(1, 'Homens'), (2, 'Mulheres')]:
            gender_df = df[df['DEMO_RIAGENDR'] == gender]
            total_valid = gender_df['target'].notna().sum()
            normal = (gender_df['target'] == 0).sum()
            osteo = (gender_df['target'] == 1).sum()
            
            print(f"\nDistribuição da variável target para {label}:")
            print(f"Normal (0): {normal} ({normal/total_valid*100:.1f}%)")
            print(f"Osteoporose (1): {osteo} ({osteo/total_valid*100:.1f}%)")
            
            print(f"\nPercentis para {label}:")
            for col in ['BMX_BMXWT', 'BMX_BMXHT', 'BMX_BMXARMC']:
                print(f"\n{col}:")
                print(gender_df[col].describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
            
            # Análise dos critérios de classificação para cada género
            print(f"\nAnálise dos critérios para {label}:")
            analyze_classification_criteria(gender_df)
        
        return df
        
    except Exception as e:
        print(f"Erro ao criar variável target: {str(e)}")
        return None

def combine_and_impute_data(dfs):
    """
    Combina diferentes ciclos do NHANES e imputa valores faltantes,
    criando flags para valores imputados
    """
    try:
        # Combinar DataFrames
        df_combined = pd.concat(dfs, ignore_index=True)
        print(f"\nShape após combinação dos ciclos: {df_combined.shape}")
        
        # Separar variáveis numéricas e categóricas
        numeric_cols = df_combined.select_dtypes(include=['float64', 'int']).columns
        categorical_cols = df_combined.select_dtypes(include=['object']).columns
        
        # Criar dicionário para armazenar flags de imputação
        imputation_flags = {}
        
        # Para cada coluna numérica, criar uma flag de valores faltantes
        for col in numeric_cols:
            imputation_flags[f"{col}_imputed"] = df_combined[col].isnull()
        
        # Imputar valores numéricos com KNN
        print("\nIniciando imputação de valores numéricos...")
        imputer = KNNImputer(n_neighbors=3)
        df_combined[numeric_cols] = imputer.fit_transform(df_combined[numeric_cols])
        
        # Imputar valores categóricos com moda e criar flags
        print("\nIniciando imputação de valores categóricos...")
        for col in categorical_cols:
            imputation_flags[f"{col}_imputed"] = df_combined[col].isnull()
            df_combined[col].fillna(df_combined[col].mode()[0], inplace=True)
        
        # Adicionar flags ao DataFrame
        for flag_name, flag_values in imputation_flags.items():
            df_combined[flag_name] = flag_values.astype(int)
        
        # Análise da imputação
        print("\nAnálise da Imputação:")
        print("-" * 50)
        
        for col in numeric_cols:
            flag_col = f"{col}_imputed"
            if flag_col in df_combined.columns:
                total_imputed = df_combined[flag_col].sum()
                imputed_class_1 = df_combined[df_combined['target'] == 1][flag_col].sum()
                imputed_class_0 = df_combined[df_combined['target'] == 0][flag_col].sum()
                
                print(f"\nColuna: {col}")
                print(f"Total de valores imputados: {total_imputed}")
                print(f"Valores imputados na classe 0: {imputed_class_0}")
                print(f"Valores imputados na classe 1: {imputed_class_1}")
                print(f"Porcentagem na classe 1: {(imputed_class_1/total_imputed*100 if total_imputed > 0 else 0):.2f}%")
                
                # Análise estatística dos valores imputados vs. não imputados
                print("\nEstatísticas dos valores:")
                print("Originais:")
                print(df_combined[df_combined[flag_col] == 0][col].describe().round(2))
                print("\nImputados:")
                print(df_combined[df_combined[flag_col] == 1][col].describe().round(2))
        
        print("\nImputação concluída com sucesso!")
        return df_combined
        
    except Exception as e:
        print(f"Erro ao combinar e imputar dados: {str(e)}")
        return None

# Exemplo de uso:
# df_final = combine_and_impute_data([df1, df2, df3])

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import gc

# Definir caminhos dos arquivos
BASE_PATH = Path('/Users/filipecarvalho/Documents/data_science_projects/BMD/paper/Computers_in_Biology_and_Medicine/NHANES')
PATHS = {
    '2013-2014': BASE_PATH / 'variaveis_selecionadas.csv',
    '2009-2010': BASE_PATH / 'NHANES_2009_2010',
    '2007-2008': BASE_PATH / 'NHANES_2007_2008'
}

# Carregar e processar dados do NHANES 2013-2014 (dados de referência)
print("\nCarregando dados NHANES 2013-2014...")
df_2013_2014 = load_and_preprocess_nhanes_2013_2014(PATHS['2013-2014'])

if df_2013_2014 is not None:
    # Obter lista de colunas de referência após processamento
    reference_columns = standardize_column_names(df_2013_2014.columns)
    print(f"\nNúmero de colunas de referência: {len(reference_columns)}")
    
    # Carregar e processar ciclos 2009-2010 e 2007-2008
    cycle_dfs = {'2013-2014': df_2013_2014}
    
    for cycle in ['2009-2010', '2007-2008']:
        print(f"\nCarregando dados NHANES {cycle}...")
        cycle_dfs[cycle] = load_nhanes_cycle(PATHS[cycle], reference_columns)
    
    # Verificar se todos os DataFrames foram carregados corretamente
    if all(df is not None for df in cycle_dfs.values()):
        print("\nTodos os ciclos foram carregados com sucesso")
        
        # Calcular T-scores para cada ciclo
        dfs_with_t_scores = {}
        for cycle, df in cycle_dfs.items():
            print(f"\nCalculando T-scores para ciclo {cycle}")
            dfs_with_t_scores[cycle] = calculate_t_scores(df)
        
        # Criar target variable para cada ciclo
        dfs_with_target = {}
        for cycle, df in dfs_with_t_scores.items():
            print(f"\nCriando variável target para ciclo {cycle}")
            df_with_target = create_target_variable(df)  # Guarda o resultado em uma nova variável
            
            if df_with_target is not None:  # Verifica se a criação da target foi bem sucedida
                dfs_with_target[cycle] = df_with_target
                
                # Mostrar informações sobre o ciclo
                print(f"\nInformações do ciclo {cycle}:")
                print(f"Shape: {df_with_target.shape}")
                if 'target' in df_with_target.columns:  # Verifica se a coluna target existe
                    print("Distribuição target:")
                    print(df_with_target['target'].value_counts(normalize=True).round(3) * 100)
                else:
                    print("ERRO: Coluna target não foi criada!")
            else:
                print(f"ERRO: Falha ao criar target para ciclo {cycle}")
        
        # Combinar todos os ciclos e imputar valores faltantes
        print("\nCombinando todos os ciclos...")  
        df_final = combine_and_impute_data(list(dfs_with_target.values()))
        df_final["BMXWT_percentil"] = df_final["BMXWT_percentil"].round(0)
        df_final["BMXARMC_percentil"] = df_final["BMXARMC_percentil"].round(0)
        df_final["ALQ_ALQ101"] = df_final["ALQ_ALQ101"].round(0)
        df_final["OCQ_OCD150"] = df_final["OCQ_OCD150"].round(0)
        df_final["PAQ_PAQ635"] = df_final["PAQ_PAQ635"].round(0)
        df_final["PAQ_PAQ650"] = df_final["PAQ_PAQ650"].round(0)
        df_final["WHQ_WHQ040"] = df_final["WHQ_WHQ040"].round(0)
        df_final["INQ_INQ030"] = df_final["INQ_INQ030"].round(0)
        df_final["INQ_INQ020"] = df_final["INQ_INQ020"].round(0)
        df_final["DIQ_DIQ180"] = df_final["DIQ_DIQ180"].round(0)
        df_final["OSQ_OSQ060"] = df_final["OSQ_OSQ060"].round(0)
        df_final["MCQ_MCQ080"] = df_final["MCQ_MCQ080"].round(0)
        df_final["WHQ_WHD050"] = df_final["WHQ_WHD050"].round(0)
        df_final["WHQ_WHQ030"] = df_final["WHQ_WHQ030"].round(0)
        df_final["BMI_percentil"] = df_final["BMI_percentil"].round(0)
        df_final["BMXWT_percentil"] = df_final["BMXWT_percentil"].astype(int)
        df_final["BMXARMC_percentil"] = df_final["BMXARMC_percentil"].astype(int)
        df_final["ALQ_ALQ101"] = df_final["ALQ_ALQ101"].astype(int)
        df_final["BPX_BPACSZ"] = df_final["BPX_BPACSZ"].round(0)
        df_final["BPX_BPACSZ"] = df_final["BPX_BPACSZ"].astype(int)
        df_final["OCQ_OCD150"] = df_final["OCQ_OCD150"].astype(int)
        df_final["WHQ_WHQ040"] = df_final["WHQ_WHQ040"].astype(int)
        df_final["INQ_INQ030"] = df_final["INQ_INQ030"].astype(int)
        df_final["INQ_INQ020"] = df_final["INQ_INQ020"].astype(int)
        df_final["DIQ_DIQ180"] = df_final["DIQ_DIQ180"].astype(int)
        df_final["OSQ_OSQ060"] = df_final["OSQ_OSQ060"].astype(int)
        df_final["MCQ_MCQ080"] = df_final["MCQ_MCQ080"].astype(int)
        df_final["WHQ_WHD050"] = df_final["WHQ_WHD050"].astype(int)
        df_final["WHQ_WHQ030"] = df_final["WHQ_WHQ030"].astype(int)
        if df_final is not None:
            print("\nProcessamento concluído com sucesso!")
            print(f"Shape final do DataFrame: {df_final.shape}")
            print("\nDistribuição final da variável target:")
            print(df_final['target'].value_counts(normalize=True).round(3) * 100)
            
            # Opcionalmente, salvar o DataFrame final
            output_path = BASE_PATH / 'nhanes_combined_processed.csv'
            df_final.to_csv(output_path, index=False)
            print(f"\nDataFrame final salvo em: {output_path}")
        else:
            print("\nErro: Falha ao combinar os ciclos")
    else:
        print("\nErro: Nem todos os ciclos foram carregados corretamente")
else:
    print("\nErro: Falha ao carregar dados de referência 2013-2014")
# Out:
# Carregando dados NHANES 2013-2014...
# Dados 2013-2014 carregados. Shape inicial: (2874, 102)
# Shape após processamento: (2874, 94)
#
# Número de colunas de referência: 94
#
# Carregando dados NHANES 2009-2010...
# Arquivo válido: APOB_F, Shape: (3581, 4)
# Arquivo válido: UHM_F, Shape: (2941, 27)
# Arquivo válido: OCQ_F, Shape: (6889, 24)
# Arquivo válido: OHXDEN_F, Shape: (8189, 39)
# Arquivo válido: WHQ_F, Shape: (6889, 63)
# Arquivo válido: HEPB_S_F, Shape: (9522, 2)
# Arquivo válido: BHQ_F, Shape: (6059, 12)
# Arquivo válido: MMRV_F, Shape: (5652, 5)
# Arquivo válido: VOCWB_F, Shape: (3745, 72)
# Arquivo válido: BPQ_F, Shape: (6889, 21)
# Arquivo válido: TRIGLY_F, Shape: (3581, 6)
# Arquivo válido: HEPE_F, Shape: (8591, 3)
# Arquivo válido: DXXFEM_F, Shape: (8185, 20)
# Arquivo válido: HEPBD_F, Shape: (8591, 4)
# Arquivo válido: CDQ_F, Shape: (4135, 17)
# Arquivo válido: DEET_F, Shape: (2831, 9)
# Arquivo válido: DIQ_F, Shape: (10109, 20)
# Arquivo válido: DEQ_F, Shape: (4145, 9)
# Arquivo válido: HEPA_F, Shape: (9522, 2)
# Arquivo válido: SSTOXO_F, Shape: (6679, 2)
# Arquivo válido: AUX_F, Shape: (2368, 71)
# Arquivo válido: GHB_F, Shape: (7369, 2)
# Arquivo válido: ALQ_F, Shape: (6059, 9)
# Arquivo válido: PFC_F, Shape: (2432, 26)
# Arquivo válido: SMQ_F, Shape: (7528, 37)
# Arquivo válido: DR1TOT_F, Shape: (10253, 166)
# Arquivo válido: INQ_F, Shape: (10537, 15)
# Arquivo válido: TFR_F, Shape: (3521, 2)
# Arquivo válido: ENX_F, Shape: (8195, 22)
# Arquivo válido: VTQ_F, Shape: (3745, 22)
# Arquivo válido: DUQ_F, Shape: (5302, 42)
# Arquivo válido: SPX_F, Shape: (8195, 51)
# Arquivo válido: ALQY_F, Shape: (301, 5)
# Arquivo válido: PBCD_F, Shape: (9835, 10)
# Arquivo válido: CBQPFC_F, Shape: (2945, 86)
# Arquivo válido: CRP_F, Shape: (9211, 2)
# Arquivo válido: DEMO_F, Shape: (10537, 43)
# Arquivo válido: ECQ_F, Shape: (3648, 10)
# Arquivo válido: AUXAR_F, Shape: (2368, 337)
# Arquivo válido: PHTHTE_F, Shape: (2819, 33)
# Arquivo válido: CBQPFA_F, Shape: (6399, 87)
# Arquivo válido: SMQFAM_F, Shape: (10537, 5)
# Arquivo válido: POOLTF_F, Shape: (2524, 3)
# Arquivo válido: OHXPER_F, Shape: (5037, 508)
# Arquivo válido: DSQTOT_F, Shape: (10537, 38)
# Arquivo válido: DS2IDS_F, Shape: (2849, 48)
# Arquivo válido: FLXCLN_F, Shape: (2532, 7)
# Arquivo válido: FOLATE_F, Shape: (9835, 5)
# Arquivo válido: VOCMWB_F, Shape: (3745, 14)
# Arquivo válido: PUQMEC_F, Shape: (8591, 3)
# Arquivo válido: FERTIN_F, Shape: (3521, 3)
# Arquivo válido: OSQ_F, Shape: (6218, 92)
# Arquivo válido: MCQ_F, Shape: (10109, 81)
# Arquivo válido: FASTQX_F, Shape: (9835, 19)
# Arquivo válido: BMX_F, Shape: (10253, 23)
# Arquivo válido: SSHPV_F, Shape: (743, 5)
# Arquivo válido: VOC_F, Shape: (3745, 12)
# Arquivo válido: HDL_F, Shape: (8591, 3)
# Arquivo válido: UCOSMO_F, Shape: (8591, 2)
# Arquivo válido: CBQ_F, Shape: (10537, 18)
# Arquivo válido: ARQ_F, Shape: (5106, 125)
# Arquivo válido: TCHOL_F, Shape: (8591, 3)
# Arquivo válido: DR1IFF_F, Shape: (9754, 85)
# Arquivo válido: FSQ_F, Shape: (10537, 44)
# Arquivo válido: DS1TOT_F, Shape: (10253, 48)
# Arquivo válido: PAQ_F, Shape: (9771, 21)
# Arquivo válido: UIO_F, Shape: (2941, 4)
# Arquivo válido: HSV_F, Shape: (4106, 3)
# Arquivo válido: OHXREF_F, Shape: (8189, 12)
# Arquivo válido: ACQ_F, Shape: (7557, 5)
# Arquivo válido: COTNAL_F, Shape: (9211, 6)
# Arquivo válido: BPX_F, Shape: (10253, 27)
# Arquivo válido: DR2TOT_F, Shape: (10253, 83)
# Arquivo válido: VIT_B6_F, Shape: (9835, 3)
# Arquivo válido: IMQ_F, Shape: (10537, 5)
# Arquivo válido: HCQ_F, Shape: (107, 38)
# Arquivo válido: HOQ_F, Shape: (10537, 7)
# Arquivo válido: SSKL_F, Shape: (2897, 2)
# Arquivo válido: EPH_F, Shape: (2819, 19)
# Arquivo válido: UAS_F, Shape: (2941, 19)
# Arquivo válido: PSA_F, Shape: (1976, 16)
# Arquivo válido: HPVSER_F, Shape: (4355, 5)
# Arquivo válido: OGTT_F, Shape: (3163, 12)
# Arquivo válido: HUQ_F, Shape: (10537, 10)
# Arquivo válido: SLQ_F, Shape: (6889, 4)
# Arquivo válido: DPQ_F, Shape: (6360, 11)
# Arquivo válido: CHLMDA_F, Shape: (2334, 2)
# Arquivo válido: GLU_F, Shape: (3581, 8)
# Arquivo válido: SMQRTU_F, Shape: (7369, 24)
# Arquivo válido: AUQ_F, Shape: (10109, 17)
# Arquivo válido: SXQ_F, Shape: (5302, 49)
# Arquivo válido: HIV_F, Shape: (4355, 2)
# Arquivo válido: PFQ_F, Shape: (9016, 35)
# Arquivo válido: DXXSPN_F, Shape: (8185, 24)
# Arquivo válido: AUXTYM_F, Shape: (2368, 169)
# Arquivo válido: UPHOPM_F, Shape: (2831, 23)
# Arquivo válido: RXQ_RX_F, Shape: (10537, 7)
# Arquivo válido: ORHPV_F, Shape: (5302, 41)
# Arquivo válido: OHQ_F, Shape: (5177, 9)
# Arquivo válido: DR2IFF_F, Shape: (8405, 85)
# Arquivo válido: DSQIDS_F, Shape: (4446, 84)
# Arquivo válido: HIQ_F, Shape: (10537, 16)
# Arquivo válido: IHG_F, Shape: (9835, 4)
# Arquivo válido: DS2TOT_F, Shape: (10253, 48)
# Arquivo válido: UCPREG_F, Shape: (1377, 2)
# Arquivo válido: SSPOLI_F, Shape: (4254, 5)
# Arquivo válido: PERNT_F, Shape: (2941, 9)
# Arquivo válido: AQQ_F, Shape: (6889, 14)
# Arquivo válido: DTQ_F, Shape: (8541, 56)
# Arquivo válido: WHQMEC_F, Shape: (1468, 25)
# Arquivo válido: UHG_F, Shape: (2941, 4)
# Arquivo válido: DBQ_F, Shape: (10537, 55)
# Arquivo válido: UCFLOW_F, Shape: (8591, 10)
# Arquivo válido: RHQ_F, Shape: (3745, 58)
# Arquivo válido: TGEMA_F, Shape: (8591, 3)
# Arquivo válido: PHYTO_F, Shape: (2941, 15)
# Arquivo válido: CBC_F, Shape: (9835, 21)
# Arquivo válido: DS1IDS_F, Shape: (2971, 48)
# Arquivo válido: ARX_F, Shape: (5001, 13)
# Arquivo válido: RDQ_F, Shape: (10109, 15)
# Arquivo válido: HPVSWR_F, Shape: (2244, 42)
# Arquivo válido: HSQ_F, Shape: (9835, 14)
# Arquivo válido: KIQ_U_F, Shape: (6218, 16)
# Arquivo válido: TFA_F, Shape: (5423, 10)
# Arquivo válido: ALB_CR_F, Shape: (8591, 11)
# Arquivo válido: SSEBV_F, Shape: (1881, 4)
# Arquivo válido: PP_F, Shape: (2819, 13)
# Arquivo válido: THYROD_F, Shape: (2544, 14)
# Arquivo válido: CAFE_F, Shape: (2831, 33)
#
# Iniciando processo de merge...
#
# Mergindo DataFrame 1 de 128
#
# Mergindo DataFrame 2 de 128
#
# Mergindo DataFrame 3 de 128
#
# Mergindo DataFrame 4 de 128
#
# Mergindo DataFrame 5 de 128
#
# Mergindo DataFrame 6 de 128
#
# Mergindo DataFrame 7 de 128
#
# Mergindo DataFrame 8 de 128
#
# Mergindo DataFrame 9 de 128
#
# Mergindo DataFrame 10 de 128
#
# Mergindo DataFrame 11 de 128
#
# Mergindo DataFrame 12 de 128
#
# Mergindo DataFrame 13 de 128
#
# Mergindo DataFrame 14 de 128
#
# Mergindo DataFrame 15 de 128
#
# Mergindo DataFrame 16 de 128
#
# Mergindo DataFrame 17 de 128
#
# Mergindo DataFrame 18 de 128
#
# Mergindo DataFrame 19 de 128
#
# Mergindo DataFrame 20 de 128
#
# Mergindo DataFrame 21 de 128
#
# Mergindo DataFrame 22 de 128
#
# Mergindo DataFrame 23 de 128
#
# Mergindo DataFrame 24 de 128
#
# Mergindo DataFrame 25 de 128
#
# Mergindo DataFrame 26 de 128
#
# Mergindo DataFrame 27 de 128
#
# Mergindo DataFrame 28 de 128
#
# Mergindo DataFrame 29 de 128
#
# Mergindo DataFrame 30 de 128
#
# Mergindo DataFrame 31 de 128
#
# Mergindo DataFrame 32 de 128
#
# Mergindo DataFrame 33 de 128
#
# Mergindo DataFrame 34 de 128
#
# Mergindo DataFrame 35 de 128
#
# Mergindo DataFrame 36 de 128
#
# Mergindo DataFrame 37 de 128
#
# Mergindo DataFrame 38 de 128
#
# Mergindo DataFrame 39 de 128
#
# Mergindo DataFrame 40 de 128
#
# Mergindo DataFrame 41 de 128
#
# Mergindo DataFrame 42 de 128
#
# Mergindo DataFrame 43 de 128
#
# Mergindo DataFrame 44 de 128
#
# Mergindo DataFrame 45 de 128
#
# Mergindo DataFrame 46 de 128
#
# Mergindo DataFrame 47 de 128
#
# Mergindo DataFrame 48 de 128
#
# Mergindo DataFrame 49 de 128
#
# Mergindo DataFrame 50 de 128
#
# Mergindo DataFrame 51 de 128
#
# Mergindo DataFrame 52 de 128
#
# Mergindo DataFrame 53 de 128
#
# Mergindo DataFrame 54 de 128
#
# Mergindo DataFrame 55 de 128
#
# Mergindo DataFrame 56 de 128
#
# Mergindo DataFrame 57 de 128
#
# Mergindo DataFrame 58 de 128
#
# Mergindo DataFrame 59 de 128
#
# Mergindo DataFrame 60 de 128
#
# Mergindo DataFrame 61 de 128
#
# Mergindo DataFrame 62 de 128
#
# Mergindo DataFrame 63 de 128
#
# Mergindo DataFrame 64 de 128
#
# Mergindo DataFrame 65 de 128
#
# Mergindo DataFrame 66 de 128
#
# Mergindo DataFrame 67 de 128
#
# Mergindo DataFrame 68 de 128
#
# Mergindo DataFrame 69 de 128
#
# Mergindo DataFrame 70 de 128
#
# Mergindo DataFrame 71 de 128
#
# Mergindo DataFrame 72 de 128
#
# Mergindo DataFrame 73 de 128
#
# Mergindo DataFrame 74 de 128
#
# Mergindo DataFrame 75 de 128
#
# Mergindo DataFrame 76 de 128
#
# Mergindo DataFrame 77 de 128
#
# Mergindo DataFrame 78 de 128
#
# Mergindo DataFrame 79 de 128
#
# Mergindo DataFrame 80 de 128
#
# Mergindo DataFrame 81 de 128
#
# Mergindo DataFrame 82 de 128
#
# Mergindo DataFrame 83 de 128
#
# Mergindo DataFrame 84 de 128
#
# Mergindo DataFrame 85 de 128
#
# Mergindo DataFrame 86 de 128
#
# Mergindo DataFrame 87 de 128
#
# Mergindo DataFrame 88 de 128
#
# Mergindo DataFrame 89 de 128
#
# Mergindo DataFrame 90 de 128
#
# Mergindo DataFrame 91 de 128
#
# Mergindo DataFrame 92 de 128
#
# Mergindo DataFrame 93 de 128
#
# Mergindo DataFrame 94 de 128
#
# Mergindo DataFrame 95 de 128
#
# Mergindo DataFrame 96 de 128
#
# Mergindo DataFrame 97 de 128
#
# Mergindo DataFrame 98 de 128
#
# Mergindo DataFrame 99 de 128
#
# Mergindo DataFrame 100 de 128
#
# Mergindo DataFrame 101 de 128
#
# Mergindo DataFrame 102 de 128
#
# Mergindo DataFrame 103 de 128
#
# Mergindo DataFrame 104 de 128
#
# Mergindo DataFrame 105 de 128
#
# Mergindo DataFrame 106 de 128
#
# Mergindo DataFrame 107 de 128
#
# Mergindo DataFrame 108 de 128
#
# Mergindo DataFrame 109 de 128
#
# Mergindo DataFrame 110 de 128
#
# Mergindo DataFrame 111 de 128
#
# Mergindo DataFrame 112 de 128
#
# Mergindo DataFrame 113 de 128
#
# Mergindo DataFrame 114 de 128
#
# Mergindo DataFrame 115 de 128
#
# Mergindo DataFrame 116 de 128
#
# Mergindo DataFrame 117 de 128
#
# Mergindo DataFrame 118 de 128
#
# Mergindo DataFrame 119 de 128
#
# Mergindo DataFrame 120 de 128
#
# Mergindo DataFrame 121 de 128
#
# Mergindo DataFrame 122 de 128
#
# Mergindo DataFrame 123 de 128
#
# Mergindo DataFrame 124 de 128
#
# Mergindo DataFrame 125 de 128
#
# Mergindo DataFrame 126 de 128
#
# Mergindo DataFrame 127 de 128
#
# Mergindo DataFrame 128 de 128
#
# Shape antes do filtro de idade: (7099, 60)
# Shape após filtro de idade (>=50 anos): (2528, 60)
#
# Distribuição de idade após filtro:
# count    2528.000000
# mean       64.941456
# std         9.560573
# min        50.000000
# 25%        57.000000
# 50%        64.000000
# 75%        73.000000
# max        80.000000
# Name: DEMO_RIDAGEYR, dtype: float64
#
# Shape final após processamento: (2528, 60)
#
# Carregando dados NHANES 2007-2008...
# Arquivo válido: WHQ_E, Shape: (6546, 58)
# Arquivo válido: HEPB_S_E, Shape: (9013, 2)
# Arquivo válido: BHQ_E, Shape: (5707, 7)
# Arquivo válido: BIOPRO_E, Shape: (6917, 37)
# Arquivo válido: VOCWB_E, Shape: (3415, 89)
# Arquivo válido: BPQ_E, Shape: (6546, 19)
# Arquivo válido: TRIGLY_E, Shape: (3315, 6)
# Arquivo válido: DXXFEM_E, Shape: (7734, 20)
# Arquivo válido: APOB_E, Shape: (3315, 4)
# Arquivo válido: UHM_E, Shape: (2720, 27)
# Arquivo válido: OPXRET_E, Shape: (3863, 222)
# Arquivo válido: OCQ_E, Shape: (6546, 24)
# Arquivo válido: HEPC_E, Shape: (8132, 4)
# Arquivo válido: DR1TOT_E, Shape: (9762, 164)
# Arquivo válido: INQ_E, Shape: (10149, 15)
# Arquivo válido: TFR_E, Shape: (3178, 2)
# Arquivo válido: CDQ_E, Shape: (4025, 17)
# Arquivo válido: DEET_E, Shape: (2694, 9)
# Arquivo válido: DIQ_E, Shape: (9666, 36)
# Arquivo válido: HEPA_E, Shape: (9013, 2)
# Arquivo válido: OPD_E, Shape: (2694, 15)
# Arquivo válido: SSUSG_E, Shape: (6559, 3)
# Arquivo válido: GHB_E, Shape: (6917, 2)
# Arquivo válido: AUX_E, Shape: (1210, 71)
# Arquivo válido: VIX_E, Shape: (6917, 57)
# Arquivo válido: ALQ_E, Shape: (5707, 9)
# Arquivo válido: PFC_E, Shape: (2294, 26)
# Arquivo válido: UPP_E, Shape: (2694, 37)
# Arquivo válido: SMQ_E, Shape: (7145, 37)
# Arquivo válido: PHTHTE_E, Shape: (2718, 33)
# Arquivo válido: CBQPFA_E, Shape: (6022, 58)
# Arquivo válido: SMQFAM_E, Shape: (10149, 5)
# Arquivo válido: POOLTF_E, Shape: (2282, 3)
# Arquivo válido: OHX_E, Shape: (8311, 59)
# Arquivo válido: DSQTOT_E, Shape: (10149, 38)
# Arquivo válido: DS2IDS_E, Shape: (2662, 46)
# Arquivo válido: FOLATE_E, Shape: (9307, 5)
# Arquivo válido: VOCMWB_E, Shape: (3415, 34)
# Arquivo válido: PUQMEC_E, Shape: (8132, 3)
# Arquivo válido: ENX_E, Shape: (7743, 22)
# Arquivo válido: DUQ_E, Shape: (4625, 37)
# Arquivo válido: SPX_E, Shape: (7743, 51)
# Arquivo válido: PBCD_E, Shape: (9307, 8)
# Arquivo válido: CBQPFC_E, Shape: (2869, 57)
# Arquivo válido: CRP_E, Shape: (8712, 2)
# Arquivo válido: DEMO_E, Shape: (10149, 43)
# Arquivo válido: ECQ_E, Shape: (3603, 14)
# Arquivo válido: AUXAR_E, Shape: (1210, 337)
# Arquivo válido: BMX_E, Shape: (9762, 23)
# Arquivo válido: VOC_E, Shape: (3415, 33)
# Arquivo válido: HDL_E, Shape: (8132, 3)
# Arquivo válido: SSQ_E, Shape: (4025, 21)
# Arquivo válido: CBQ_E, Shape: (10149, 18)
# Arquivo válido: TCHOL_E, Shape: (8132, 3)
# Arquivo válido: DR1IFF_E, Shape: (9254, 85)
# Arquivo válido: FSQ_E, Shape: (10149, 44)
# Arquivo válido: DS1TOT_E, Shape: (9762, 47)
# Arquivo válido: PAQ_E, Shape: (9359, 21)
# Arquivo válido: PAH_E, Shape: (2718, 21)
# Arquivo válido: FERTIN_E, Shape: (3178, 3)
# Arquivo válido: OSQ_E, Shape: (5935, 105)
# Arquivo válido: MCQ_E, Shape: (9666, 92)
# Arquivo válido: FASTQX_E, Shape: (9307, 19)
# Arquivo válido: VIT_B6_E, Shape: (9307, 3)
# Arquivo válido: IMQ_E, Shape: (10149, 5)
# Arquivo válido: HCQ_E, Shape: (116, 38)
# Arquivo válido: HOQ_E, Shape: (10149, 7)
# Arquivo válido: SSKL_E, Shape: (3006, 2)
# Arquivo válido: KIQ_P_E, Shape: (5707, 9)
# Arquivo válido: EPH_E, Shape: (2718, 19)
# Arquivo válido: UAS_E, Shape: (2720, 19)
# Arquivo válido: UIO_E, Shape: (8132, 3)
# Arquivo válido: CARB_E, Shape: (2694, 15)
# Arquivo válido: HSV_E, Shape: (3690, 3)
# Arquivo válido: ACQ_E, Shape: (7173, 5)
# Arquivo válido: COTNAL_E, Shape: (8712, 6)
# Arquivo válido: BPX_E, Shape: (9762, 27)
# Arquivo válido: DR2TOT_E, Shape: (9762, 83)
# Arquivo válido: SLQ_E, Shape: (6546, 28)
# Arquivo válido: DPQ_E, Shape: (5995, 11)
# Arquivo válido: CHLMDA_E, Shape: (2132, 3)
# Arquivo válido: GLU_E, Shape: (3315, 8)
# Arquivo válido: SSHCV_E, Shape: (380, 10)
# Arquivo válido: VIQ_E, Shape: (7173, 18)
# Arquivo válido: AUQ_E, Shape: (9666, 17)
# Arquivo válido: SMQRTU_E, Shape: (6917, 24)
# Arquivo válido: SXQ_E, Shape: (4625, 29)
# Arquivo válido: HIV_E, Shape: (3059, 2)
# Arquivo válido: PFQ_E, Shape: (9666, 55)
# Arquivo válido: HPVSER_E, Shape: (3950, 5)
# Arquivo válido: OPXFDT_E, Shape: (3863, 96)
# Arquivo válido: OGTT_E, Shape: (3315, 12)
# Arquivo válido: HUQ_E, Shape: (10149, 10)
# Arquivo válido: UCPREG_E, Shape: (1180, 2)
# Arquivo válido: PERNT_E, Shape: (8132, 8)
# Arquivo válido: AQQ_E, Shape: (6546, 14)
# Arquivo válido: WHQMEC_E, Shape: (1427, 25)
# Arquivo válido: UHG_E, Shape: (2720, 4)
# Arquivo válido: DXXSPN_E, Shape: (7734, 35)
# Arquivo válido: AUXTYM_E, Shape: (1210, 169)
# Arquivo válido: UPHOPM_E, Shape: (2694, 23)
# Arquivo válido: RXQ_RX_E, Shape: (10149, 7)
# Arquivo válido: OHQ_E, Shape: (6228, 9)
# Arquivo válido: DR2IFF_E, Shape: (7837, 85)
# Arquivo válido: DSQIDS_E, Shape: (4042, 82)
# Arquivo válido: HIQ_E, Shape: (10149, 17)
# Arquivo válido: IHG_E, Shape: (9307, 4)
# Arquivo válido: DS2TOT_E, Shape: (9762, 47)
# Arquivo válido: HPVSWR_E, Shape: (1998, 43)
# Arquivo válido: HSQ_E, Shape: (9307, 14)
# Arquivo válido: KIQ_U_E, Shape: (5935, 16)
# Arquivo válido: UAM_E, Shape: (2694, 15)
# Arquivo válido: ALB_CR_E, Shape: (8132, 5)
# Arquivo válido: SSEBV_E, Shape: (1844, 4)
# Arquivo válido: THYROD_E, Shape: (6917, 13)
# Arquivo válido: PP_E, Shape: (2718, 13)
# Arquivo válido: FOLFMS_E, Shape: (3122, 6)
# Arquivo válido: DBQ_E, Shape: (10149, 54)
# Arquivo válido: RHQ_E, Shape: (3484, 58)
# Arquivo válido: PHYTO_E, Shape: (2718, 15)
# Arquivo válido: DS1IDS_E, Shape: (2769, 46)
# Arquivo válido: CBC_E, Shape: (9307, 21)
# Arquivo válido: RDQ_E, Shape: (9666, 15)
#
# Iniciando processo de merge...
#
# Mergindo DataFrame 1 de 122
#
# Mergindo DataFrame 2 de 122
#
# Mergindo DataFrame 3 de 122
#
# Mergindo DataFrame 4 de 122
#
# Mergindo DataFrame 5 de 122
#
# Mergindo DataFrame 6 de 122
#
# Mergindo DataFrame 7 de 122
#
# Mergindo DataFrame 8 de 122
#
# Mergindo DataFrame 9 de 122
#
# Mergindo DataFrame 10 de 122
#
# Mergindo DataFrame 11 de 122
#
# Mergindo DataFrame 12 de 122
#
# Mergindo DataFrame 13 de 122
#
# Mergindo DataFrame 14 de 122
#
# Mergindo DataFrame 15 de 122
#
# Mergindo DataFrame 16 de 122
#
# Mergindo DataFrame 17 de 122
#
# Mergindo DataFrame 18 de 122
#
# Mergindo DataFrame 19 de 122
#
# Mergindo DataFrame 20 de 122
#
# Mergindo DataFrame 21 de 122
#
# Mergindo DataFrame 22 de 122
#
# Mergindo DataFrame 23 de 122
#
# Mergindo DataFrame 24 de 122
#
# Mergindo DataFrame 25 de 122
#
# Mergindo DataFrame 26 de 122
#
# Mergindo DataFrame 27 de 122
#
# Mergindo DataFrame 28 de 122
#
# Mergindo DataFrame 29 de 122
#
# Mergindo DataFrame 30 de 122
#
# Mergindo DataFrame 31 de 122
#
# Mergindo DataFrame 32 de 122
#
# Mergindo DataFrame 33 de 122
#
# Mergindo DataFrame 34 de 122
#
# Mergindo DataFrame 35 de 122
#
# Mergindo DataFrame 36 de 122
#
# Mergindo DataFrame 37 de 122
#
# Mergindo DataFrame 38 de 122
#
# Mergindo DataFrame 39 de 122
#
# Mergindo DataFrame 40 de 122
#
# Mergindo DataFrame 41 de 122
#
# Mergindo DataFrame 42 de 122
#
# Mergindo DataFrame 43 de 122
#
# Mergindo DataFrame 44 de 122
#
# Mergindo DataFrame 45 de 122
#
# Mergindo DataFrame 46 de 122
#
# Mergindo DataFrame 47 de 122
#
# Mergindo DataFrame 48 de 122
#
# Mergindo DataFrame 49 de 122
#
# Mergindo DataFrame 50 de 122
#
# Mergindo DataFrame 51 de 122
#
# Mergindo DataFrame 52 de 122
#
# Mergindo DataFrame 53 de 122
#
# Mergindo DataFrame 54 de 122
#
# Mergindo DataFrame 55 de 122
#
# Mergindo DataFrame 56 de 122
#
# Mergindo DataFrame 57 de 122
#
# Mergindo DataFrame 58 de 122
#
# Mergindo DataFrame 59 de 122
#
# Mergindo DataFrame 60 de 122
#
# Mergindo DataFrame 61 de 122
#
# Mergindo DataFrame 62 de 122
#
# Mergindo DataFrame 63 de 122
#
# Mergindo DataFrame 64 de 122
#
# Mergindo DataFrame 65 de 122
#
# Mergindo DataFrame 66 de 122
#
# Mergindo DataFrame 67 de 122
#
# Mergindo DataFrame 68 de 122
#
# Mergindo DataFrame 69 de 122
#
# Mergindo DataFrame 70 de 122
#
# Mergindo DataFrame 71 de 122
#
# Mergindo DataFrame 72 de 122
#
# Mergindo DataFrame 73 de 122
#
# Mergindo DataFrame 74 de 122
#
# Mergindo DataFrame 75 de 122
#
# Mergindo DataFrame 76 de 122
#
# Mergindo DataFrame 77 de 122
#
# Mergindo DataFrame 78 de 122
#
# Mergindo DataFrame 79 de 122
#
# Mergindo DataFrame 80 de 122
#
# Mergindo DataFrame 81 de 122
#
# Mergindo DataFrame 82 de 122
#
# Mergindo DataFrame 83 de 122
#
# Mergindo DataFrame 84 de 122
#
# Mergindo DataFrame 85 de 122
#
# Mergindo DataFrame 86 de 122
#
# Mergindo DataFrame 87 de 122
#
# Mergindo DataFrame 88 de 122
#
# Mergindo DataFrame 89 de 122
#
# Mergindo DataFrame 90 de 122
#
# Mergindo DataFrame 91 de 122
#
# Mergindo DataFrame 92 de 122
#
# Mergindo DataFrame 93 de 122
#
# Mergindo DataFrame 94 de 122
#
# Mergindo DataFrame 95 de 122
#
# Mergindo DataFrame 96 de 122
#
# Mergindo DataFrame 97 de 122
#
# Mergindo DataFrame 98 de 122
#
# Mergindo DataFrame 99 de 122
#
# Mergindo DataFrame 100 de 122
#
# Mergindo DataFrame 101 de 122
#
# Mergindo DataFrame 102 de 122
#
# Mergindo DataFrame 103 de 122
#
# Mergindo DataFrame 104 de 122
#
# Mergindo DataFrame 105 de 122
#
# Mergindo DataFrame 106 de 122
#
# Mergindo DataFrame 107 de 122
#
# Mergindo DataFrame 108 de 122
#
# Mergindo DataFrame 109 de 122
#
# Mergindo DataFrame 110 de 122
#
# Mergindo DataFrame 111 de 122
#
# Mergindo DataFrame 112 de 122
#
# Mergindo DataFrame 113 de 122
#
# Mergindo DataFrame 114 de 122
#
# Mergindo DataFrame 115 de 122
#
# Mergindo DataFrame 116 de 122
#
# Mergindo DataFrame 117 de 122
#
# Mergindo DataFrame 118 de 122
#
# Mergindo DataFrame 119 de 122
#
# Mergindo DataFrame 120 de 122
#
# Mergindo DataFrame 121 de 122
#
# Mergindo DataFrame 122 de 122
#
# Shape antes do filtro de idade: (6711, 48)
# Shape após filtro de idade (>=50 anos): (2522, 48)
#
# Distribuição de idade após filtro:
# count    2522.000000
# mean       65.042030
# std         9.533705
# min        50.000000
# 25%        57.000000
# 50%        64.000000
# 75%        73.000000
# max        80.000000
# Name: DEMO_RIDAGEYR, dtype: float64
#
# Shape final após processamento: (2522, 48)
#
# Todos os ciclos foram carregados com sucesso
#
# Calculando T-scores para ciclo 2013-2014
# T-scores calculados para 2874 registros
#
# Calculando T-scores para ciclo 2009-2010
# T-scores calculados para 2528 registros
#
# Calculando T-scores para ciclo 2007-2008
# T-scores calculados para 2522 registros
#
# Criando variável target para ciclo 2013-2014
#
# Distribuição da variável target para Homens:
# Normal (0): 1186 (86.5%)
# Osteoporose (1): 185 (13.5%)
#
# Percentis para Homens:
#
# BMX_BMXWT:
# count    1371.000000
# mean       86.732837
# std        19.752159
# min        43.800000
# 5%         60.650000
# 10%        65.300000
# 25%        73.300000
# 50%        83.800000
# 75%        96.700000
# 90%       110.600000
# 95%       120.400000
# max       195.400000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1371.000000
# mean      173.804041
# std         7.724769
# min       150.800000
# 5%        161.650000
# 10%       164.000000
# 25%       168.700000
# 50%       173.500000
# 75%       179.000000
# 90%       183.900000
# 95%       186.900000
# max       198.200000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1371.000000
# mean       33.719985
# std         4.479384
# min        20.000000
# 5%         27.100000
# 10%        28.500000
# 25%        30.800000
# 50%        33.300000
# 75%        36.250000
# 90%        39.300000
# 95%        41.250000
# max        55.700000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Homens:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 79 casos (42.7% dos positivos)
# All T-scores ≤ -1.0: 100 casos (54.1% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 92 casos (49.7% dos positivos)
# Arm circumference (lowest percentile): 97 casos (52.4% dos positivos)
#
# Distribuição da variável target para Mulheres:
# Normal (0): 1089 (72.5%)
# Osteoporose (1): 414 (27.5%)
#
# Percentis para Mulheres:
#
# BMX_BMXWT:
# count    1503.000000
# mean       75.787758
# std        19.598935
# min        32.300000
# 5%         49.300000
# 10%        53.620000
# 25%        62.200000
# 50%        72.300000
# 75%        86.600000
# 90%       102.680000
# 95%       112.900000
# max       173.600000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1503.000000
# mean      159.923713
# std         7.093109
# min       135.400000
# 5%        148.200000
# 10%       150.820000
# 25%       154.900000
# 50%       160.100000
# 75%       164.750000
# 90%       168.900000
# 95%       171.400000
# max       183.800000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1503.000000
# mean       32.306667
# std         5.300667
# min        17.800000
# 5%         24.700000
# 10%        26.100000
# 25%        28.450000
# 50%        31.800000
# 75%        35.500000
# 90%        39.400000
# 95%        41.800000
# max        56.500000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Mulheres:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 198 casos (47.8% dos positivos)
# All T-scores ≤ -1.0: 271 casos (65.5% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 101 casos (24.4% dos positivos)
# Arm circumference (lowest percentile): 103 casos (24.9% dos positivos)
#
# Informações do ciclo 2013-2014:
# Shape: (2874, 104)
# Distribuição target:
# target
# 0    79.2
# 1    20.8
# Name: proportion, dtype: float64
#
# Criando variável target para ciclo 2009-2010
#
# Distribuição da variável target para Homens:
# Normal (0): 1091 (84.9%)
# Osteoporose (1): 194 (15.1%)
#
# Percentis para Homens:
#
# BMX_BMXWT:
# count    1282.000000
# mean       85.345944
# std        16.537914
# min        40.100000
# 5%         61.520000
# 10%        65.700000
# 25%        74.000000
# 50%        83.700000
# 75%        95.000000
# 90%       107.390000
# 95%       116.985000
# max       136.400000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1279.000000
# mean      173.200313
# std         7.690875
# min       148.000000
# 5%        160.700000
# 10%       163.300000
# 25%       167.850000
# 50%       173.200000
# 75%       178.300000
# 90%       182.900000
# 95%       185.920000
# max       201.600000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1278.000000
# mean       33.152426
# std         3.913432
# min        19.000000
# 5%         26.985000
# 10%        28.200000
# 25%        30.500000
# 50%        33.000000
# 75%        35.600000
# 90%        38.200000
# 95%        40.000000
# max        46.100000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Homens:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 104 casos (53.6% dos positivos)
# All T-scores ≤ -1.0: 49 casos (25.3% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 87 casos (44.8% dos positivos)
# Arm circumference (lowest percentile): 91 casos (46.9% dos positivos)
#
# Distribuição da variável target para Mulheres:
# Normal (0): 902 (72.6%)
# Osteoporose (1): 341 (27.4%)
#
# Percentis para Mulheres:
#
# BMX_BMXWT:
# count    1237.000000
# mean       74.699192
# std        17.094395
# min        33.200000
# 5%         50.200000
# 10%        53.800000
# 25%        62.400000
# 50%        72.000000
# 75%        85.200000
# 90%        99.240000
# 95%       106.940000
# max       135.400000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1237.000000
# mean      158.908003
# std         7.323727
# min       123.300000
# 5%        146.600000
# 10%       149.400000
# 25%       153.800000
# 50%       158.800000
# 75%       163.900000
# 90%       168.400000
# 95%       170.500000
# max       180.700000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1230.000000
# mean       32.293496
# std         4.916562
# min        17.900000
# 5%         25.100000
# 10%        26.200000
# 25%        29.000000
# 50%        31.900000
# 75%        35.175000
# 90%        38.900000
# 95%        41.200000
# max        53.500000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Mulheres:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 197 casos (57.8% dos positivos)
# All T-scores ≤ -1.0: 139 casos (40.8% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 83 casos (24.3% dos positivos)
# Arm circumference (lowest percentile): 82 casos (24.0% dos positivos)
#
# Informações do ciclo 2009-2010:
# Shape: (2528, 70)
# Distribuição target:
# target
# 0    78.8
# 1    21.2
# Name: proportion, dtype: float64
#
# Criando variável target para ciclo 2007-2008
#
# Distribuição da variável target para Homens:
# Normal (0): 1097 (87.1%)
# Osteoporose (1): 163 (12.9%)
#
# Percentis para Homens:
#
# BMX_BMXWT:
# count    1252.000000
# mean       85.713179
# std        17.415232
# min        43.100000
# 5%         59.455000
# 10%        65.100000
# 25%        73.400000
# 50%        83.800000
# 75%        95.925000
# 90%       109.090000
# 95%       119.145000
# max       136.000000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1254.000000
# mean      173.093700
# std         7.524927
# min       142.100000
# 5%        160.965000
# 10%       163.430000
# 25%       167.725000
# 50%       173.200000
# 75%       178.075000
# 90%       183.000000
# 95%       185.200000
# max       197.300000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1251.000000
# mean       33.206555
# std         4.132171
# min        20.300000
# 5%         26.600000
# 10%        28.000000
# 25%        30.500000
# 50%        33.100000
# 75%        35.900000
# 90%        38.500000
# 95%        40.100000
# max        47.900000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Homens:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 84 casos (51.5% dos positivos)
# All T-scores ≤ -1.0: 56 casos (34.4% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 86 casos (52.8% dos positivos)
# Arm circumference (lowest percentile): 84 casos (51.5% dos positivos)
#
# Distribuição da variável target para Mulheres:
# Normal (0): 923 (73.1%)
# Osteoporose (1): 339 (26.9%)
#
# Percentis para Mulheres:
#
# BMX_BMXWT:
# count    1254.000000
# mean       73.943700
# std        16.794424
# min        37.300000
# 5%         50.565000
# 10%        54.700000
# 25%        62.000000
# 50%        71.700000
# 75%        83.700000
# 90%        96.870000
# 95%       105.035000
# max       136.000000
# Name: BMX_BMXWT, dtype: float64
#
# BMX_BMXHT:
# count    1256.000000
# mean      159.251354
# std         6.998764
# min       139.600000
# 5%        147.775000
# 10%       150.400000
# 25%       154.300000
# 50%       159.500000
# 75%       164.000000
# 90%       168.300000
# 95%       170.225000
# max       186.400000
# Name: BMX_BMXHT, dtype: float64
#
# BMX_BMXARMC:
# count    1253.000000
# mean       32.019633
# std         5.064382
# min        18.600000
# 5%         24.660000
# 10%        26.000000
# 25%        28.500000
# 50%        31.400000
# 75%        35.200000
# 90%        38.500000
# 95%        40.880000
# max        55.500000
# Name: BMX_BMXARMC, dtype: float64
#
# Análise dos critérios para Mulheres:
#
# Critérios de classificação para casos positivos:
# T-score ≤ -2.5: 194 casos (57.2% dos positivos)
# All T-scores ≤ -1.0: 167 casos (49.3% dos positivos)
# Age (highest percentile): 0 casos (0.0% dos positivos)
# Weight (lowest percentile): 84 casos (24.8% dos positivos)
# Arm circumference (lowest percentile): 86 casos (25.4% dos positivos)
#
# Informações do ciclo 2007-2008:
# Shape: (2522, 58)
# Distribuição target:
# target
# 0    80.1
# 1    19.9
# Name: proportion, dtype: float64
#
# Combinando todos os ciclos...
#
# Shape após combinação dos ciclos: (7924, 104)
#
# Iniciando imputação de valores numéricos...
#
# Iniciando imputação de valores categóricos...
#
# Análise da Imputação:
# --------------------------------------------------
#
# Coluna: DEMO_RIAGENDR
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        1.51
# std         0.50
# min         1.00
# 25%         1.00
# 50%         2.00
# 75%         2.00
# max         2.00
# Name: DEMO_RIAGENDR, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: DEMO_RIAGENDR, dtype: float64
#
# Coluna: DEMO_RIDRETH1
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        2.95
# std         1.07
# min         1.00
# 25%         3.00
# 50%         3.00
# 75%         4.00
# max         5.00
# Name: DEMO_RIDRETH1, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: DEMO_RIDRETH1, dtype: float64
#
# Coluna: DXXFEM_DXXNKBMD
# Total de valores imputados: 199
# Valores imputados na classe 0: 176
# Valores imputados na classe 1: 23
# Porcentagem na classe 1: 11.56%
#
# Estatísticas dos valores:
# Originais:
# count    7725.00
# mean        0.78
# std         0.14
# min         0.33
# 25%         0.68
# 50%         0.77
# 75%         0.87
# max         1.38
# Name: DXXFEM_DXXNKBMD, dtype: float64
#
# Imputados:
# count    199.00
# mean       0.81
# std        0.08
# min        0.60
# 25%        0.74
# 50%        0.82
# 75%        0.87
# max        1.04
# Name: DXXFEM_DXXNKBMD, dtype: float64
#
# Coluna: DXXFEM_DXXOFBMD
# Total de valores imputados: 199
# Valores imputados na classe 0: 176
# Valores imputados na classe 1: 23
# Porcentagem na classe 1: 11.56%
#
# Estatísticas dos valores:
# Originais:
# count    7725.00
# mean        0.93
# std         0.16
# min         0.33
# 25%         0.82
# 50%         0.93
# 75%         1.04
# max         1.56
# Name: DXXFEM_DXXOFBMD, dtype: float64
#
# Imputados:
# count    199.00
# mean       0.95
# std        0.12
# min        0.67
# 25%        0.86
# 50%        0.97
# 75%        1.04
# max        1.18
# Name: DXXFEM_DXXOFBMD, dtype: float64
#
# Coluna: DXXSPN_DXXOSBMD
# Total de valores imputados: 1758
# Valores imputados na classe 0: 1354
# Valores imputados na classe 1: 404
# Porcentagem na classe 1: 22.98%
#
# Estatísticas dos valores:
# Originais:
# count    6166.00
# mean        1.00
# std         0.16
# min         0.45
# 25%         0.89
# 50%         1.00
# 75%         1.11
# max         1.90
# Name: DXXSPN_DXXOSBMD, dtype: float64
#
# Imputados:
# count    1758.00
# mean        1.00
# std         0.11
# min         0.72
# 25%         0.94
# 50%         1.00
# 75%         1.08
# max         1.26
# Name: DXXSPN_DXXOSBMD, dtype: float64
#
# Coluna: BPX_BPACSZ
# Total de valores imputados: 73
# Valores imputados na classe 0: 58
# Valores imputados na classe 1: 15
# Porcentagem na classe 1: 20.55%
#
# Estatísticas dos valores:
# Originais:
# count    7851.00
# mean        3.89
# std         0.64
# min         1.00
# 25%         3.00
# 50%         4.00
# 75%         4.00
# max         5.00
# Name: BPX_BPACSZ, dtype: float64
#
# Imputados:
# count    73.00
# mean      3.80
# std       0.44
# min       2.67
# 25%       3.67
# 50%       4.00
# 75%       4.00
# max       4.67
# Name: BPX_BPACSZ, dtype: float64
#
# Coluna: INQ_INQ030
# Total de valores imputados: 18
# Valores imputados na classe 0: 13
# Valores imputados na classe 1: 5
# Porcentagem na classe 1: 27.78%
#
# Estatísticas dos valores:
# Originais:
# count    7906.00
# mean        1.51
# std         0.61
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         2.00
# max         9.00
# Name: INQ_INQ030, dtype: float64
#
# Imputados:
# count    18.00
# mean      1.54
# std       0.28
# min       1.00
# 25%       1.33
# 50%       1.50
# 75%       1.67
# max       2.00
# Name: INQ_INQ030, dtype: float64
#
# Coluna: WHQ_WHQ030
# Total de valores imputados: 12
# Valores imputados na classe 0: 9
# Valores imputados na classe 1: 3
# Porcentagem na classe 1: 25.00%
#
# Estatísticas dos valores:
# Originais:
# count    7912.00
# mean        1.85
# std         1.02
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         3.00
# max         9.00
# Name: WHQ_WHQ030, dtype: float64
#
# Imputados:
# count    12.00
# mean      2.64
# std       1.15
# min       1.00
# 25%       1.67
# 50%       2.50
# 75%       3.00
# max       5.00
# Name: WHQ_WHQ030, dtype: float64
#
# Coluna: MCQ_MCQ080
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        1.62
# std         0.51
# min         1.00
# 25%         1.00
# 50%         2.00
# 75%         2.00
# max         9.00
# Name: MCQ_MCQ080, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: MCQ_MCQ080, dtype: float64
#
# Coluna: DEMO_RIDAGEYR
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean       62.66
# std        10.92
# min        40.00
# 25%        54.00
# 50%        62.00
# 75%        71.00
# max        80.00
# Name: DEMO_RIDAGEYR, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: DEMO_RIDAGEYR, dtype: float64
#
# Coluna: BMX_BMXARMC
# Total de valores imputados: 38
# Valores imputados na classe 0: 28
# Valores imputados na classe 1: 10
# Porcentagem na classe 1: 26.32%
#
# Estatísticas dos valores:
# Originais:
# count    7886.00
# mean       32.78
# std         4.72
# min        17.80
# 25%        29.50
# 50%        32.50
# 75%        35.60
# max        56.50
# Name: BMX_BMXARMC, dtype: float64
#
# Imputados:
# count    38.00
# mean     32.52
# std       4.93
# min      24.20
# 25%      28.85
# 50%      32.10
# 75%      36.09
# max      42.00
# Name: BMX_BMXARMC, dtype: float64
#
# Coluna: OSQ_OSQ080
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        1.74
# std         0.48
# min         1.00
# 25%         1.00
# 50%         2.00
# 75%         2.00
# max         9.00
# Name: OSQ_OSQ080, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: OSQ_OSQ080, dtype: float64
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_combined[flag_name] = flag_values.astype(int)
# /var/folders/q3/ycc4hmlj3493q0x11zn3vgcc0000gn/T/ipykernel_4164/2045380523.py:313: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
# Total de valores imputados: 3004
# Valores imputados na classe 0: 2375
# Valores imputados na classe 1: 629
# Porcentagem na classe 1: 20.94%
#
# Estatísticas dos valores:
# Originais:
# count    4920.00
# mean       29.42
# std        44.11
# min       -10.00
# 25%         0.00
# 50%         1.00
# 75%        99.00
# max        99.00
# Name: OHXPER_OHX09CJD, dtype: float64
#
# Imputados:
# count    3004.00
# mean       44.18
# std        28.77
# min        -2.00
# 25%        32.67
# 50%        33.67
# 75%        66.00
# max        99.00
# Name: OHXPER_OHX09CJD, dtype: float64
#
# Coluna: DS1TOT_DS1DSCNT
# Total de valores imputados: 125
# Valores imputados na classe 0: 78
# Valores imputados na classe 1: 47
# Porcentagem na classe 1: 37.60%
#
# Estatísticas dos valores:
# Originais:
# count    7799.00
# mean        1.28
# std         1.91
# min         0.00
# 25%         0.00
# 50%         1.00
# 75%         2.00
# max        28.00
# Name: DS1TOT_DS1DSCNT, dtype: float64
#
# Imputados:
# count    125.00
# mean       1.63
# std        1.24
# min        0.00
# 25%        0.67
# 50%        1.33
# 75%        2.33
# max        5.33
# Name: DS1TOT_DS1DSCNT, dtype: float64
#
# Coluna: DXXVFA_DXXT12FX
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean        0.02
# std         0.23
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         3.00
# Name: DXXVFA_DXXT12FX, dtype: float64
#
# Imputados:
# count    5050.00
# mean        0.03
# std         0.13
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.33
# Name: DXXVFA_DXXT12FX, dtype: float64
#
# Coluna: BPX_BPXDI2
# Total de valores imputados: 279
# Valores imputados na classe 0: 189
# Valores imputados na classe 1: 90
# Porcentagem na classe 1: 32.26%
#
# Estatísticas dos valores:
# Originais:
# count    7645.00
# mean       69.49
# std        14.14
# min         0.00
# 25%        62.00
# 50%        70.00
# 75%        78.00
# max       134.00
# Name: BPX_BPXDI2, dtype: float64
#
# Imputados:
# count    279.00
# mean      69.32
# std        8.02
# min       40.00
# 25%       64.67
# 50%       70.67
# 75%       74.67
# max       85.33
# Name: BPX_BPXDI2, dtype: float64
#
# Coluna: DR1TOT_DR1TSFAT
# Total de valores imputados: 123
# Valores imputados na classe 0: 76
# Valores imputados na classe 1: 47
# Porcentagem na classe 1: 38.21%
#
# Estatísticas dos valores:
# Originais:
# count    7801.00
# mean       23.60
# std        15.00
# min         0.00
# 25%        13.28
# 50%        20.50
# 75%        30.36
# max       172.20
# Name: DR1TOT_DR1TSFAT, dtype: float64
#
# Imputados:
# count    123.00
# mean      22.18
# std        7.68
# min        6.18
# 25%       17.10
# 50%       21.37
# 75%       26.82
# max       50.10
# Name: DR1TOT_DR1TSFAT, dtype: float64
#
# Coluna: WHQ_WHD140
# Total de valores imputados: 32
# Valores imputados na classe 0: 19
# Valores imputados na classe 1: 13
# Porcentagem na classe 1: 40.62%
#
# Estatísticas dos valores:
# Originais:
# count    7892.00
# mean      316.73
# std      1085.55
# min        97.00
# 25%       160.00
# 50%       187.00
# 75%       220.00
# max      9999.00
# Name: WHQ_WHD140, dtype: float64
#
# Imputados:
# count      32.00
# mean      687.22
# std      1202.60
# min       118.67
# 25%       150.75
# 50%       179.00
# 75%       241.92
# max      3444.67
# Name: WHQ_WHD140, dtype: float64
#
# Coluna: OHXPER_OHX09CJA
# Total de valores imputados: 3004
# Valores imputados na classe 0: 2375
# Valores imputados na classe 1: 629
# Porcentagem na classe 1: 20.94%
#
# Estatísticas dos valores:
# Originais:
# count    4920.00
# mean       29.67
# std        44.14
# min        -7.00
# 25%         0.00
# 50%         1.00
# 75%        99.00
# max        99.00
# Name: OHXPER_OHX09CJA, dtype: float64
#
# Imputados:
# count    3004.00
# mean       46.46
# std        27.35
# min        -2.33
# 25%        32.67
# 50%        33.67
# 75%        66.33
# max        99.00
# Name: OHXPER_OHX09CJA, dtype: float64
#
# Coluna: BMX_BMXHT
# Total de valores imputados: 24
# Valores imputados na classe 0: 18
# Valores imputados na classe 1: 6
# Porcentagem na classe 1: 25.00%
#
# Estatísticas dos valores:
# Originais:
# count    7900.00
# mean      166.31
# std        10.18
# min       123.30
# 25%       158.90
# 50%       166.10
# 75%       173.62
# max       201.60
# Name: BMX_BMXHT, dtype: float64
#
# Imputados:
# count     24.00
# mean     166.87
# std        7.15
# min      154.77
# 25%      160.20
# 50%      168.48
# 75%      173.06
# max      177.23
# Name: BMX_BMXHT, dtype: float64
#
# Coluna: DXXT7_DXXPT16Y
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean      191.48
# std        26.51
# min       107.00
# 25%       174.10
# 50%       191.40
# 75%       207.70
# max       292.90
# Name: DXXT7_DXXPT16Y, dtype: float64
#
# Imputados:
# count    5050.00
# mean      190.72
# std        14.67
# min       127.10
# 25%       181.14
# 50%       190.67
# 75%       200.17
# max       245.93
# Name: DXXT7_DXXPT16Y, dtype: float64
#
# Coluna: DR2TOT_DR2TATOA
# Total de valores imputados: 640
# Valores imputados na classe 0: 478
# Valores imputados na classe 1: 162
# Porcentagem na classe 1: 25.31%
#
# Estatísticas dos valores:
# Originais:
# count    7284.00
# mean        0.67
# std         3.25
# min        -0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max        82.92
# Name: DR2TOT_DR2TATOA, dtype: float64
#
# Imputados:
# count    640.00
# mean       0.82
# std        2.51
# min       -0.00
# 25%        0.00
# 50%        0.00
# 75%        0.10
# max       21.38
# Name: DR2TOT_DR2TATOA, dtype: float64
#
# Coluna: OHXPER_OHX31CJS
# Total de valores imputados: 3009
# Valores imputados na classe 0: 2378
# Valores imputados na classe 1: 631
# Porcentagem na classe 1: 20.97%
#
# Estatísticas dos valores:
# Originais:
# count    4915.00
# mean       45.24
# std        48.20
# min        -6.00
# 25%         0.00
# 50%         1.00
# 75%        99.00
# max        99.00
# Name: OHXPER_OHX31CJS, dtype: float64
#
# Imputados:
# count    3009.00
# mean       53.26
# std        27.08
# min        -1.33
# 25%        32.67
# 50%        65.00
# 75%        66.33
# max        99.00
# Name: OHXPER_OHX31CJS, dtype: float64
#
# Coluna: OHXPER_OHX08PCD
# Total de valores imputados: 3003
# Valores imputados na classe 0: 2375
# Valores imputados na classe 1: 628
# Porcentagem na classe 1: 20.91%
#
# Estatísticas dos valores:
# Originais:
# count    4921.00
# mean       29.82
# std        43.20
# min         0.00
# 25%         1.00
# 50%         2.00
# 75%        99.00
# max        99.00
# Name: OHXPER_OHX08PCD, dtype: float64
#
# Imputados:
# count    3003.00
# mean       36.41
# std        25.34
# min         0.67
# 25%         3.17
# 50%        34.67
# 75%        66.67
# max        99.00
# Name: OHXPER_OHX08PCD, dtype: float64
#
# Coluna: MGX_MGXH2T1
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean       31.72
# std        10.23
# min         5.50
# 25%        24.30
# 50%        30.30
# 75%        38.78
# max        79.50
# Name: MGX_MGXH2T1, dtype: float64
#
# Imputados:
# count    5050.00
# mean       31.22
# std         6.02
# min        12.90
# 25%        26.70
# 50%        31.00
# 75%        35.19
# max        55.40
# Name: MGX_MGXH2T1, dtype: float64
#
# Coluna: PAQ_PAQ605
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        1.85
# std         0.36
# min         1.00
# 25%         2.00
# 50%         2.00
# 75%         2.00
# max         2.00
# Name: PAQ_PAQ605, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: PAQ_PAQ605, dtype: float64
#
# Coluna: MGX_MGD130
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean        1.14
# std         0.43
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max         3.00
# Name: MGX_MGD130, dtype: float64
#
# Imputados:
# count    5050.00
# mean        1.14
# std         0.24
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.33
# max         2.33
# Name: MGX_MGD130, dtype: float64
#
# Coluna: DXXT8_DXXPOSTH
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean       56.89
# std         4.50
# min        43.40
# 25%        53.70
# 50%        56.70
# 75%        60.00
# max        74.40
# Name: DXXT8_DXXPOSTH, dtype: float64
#
# Imputados:
# count    5050.00
# mean       56.84
# std         2.65
# min        48.30
# 25%        54.97
# 50%        56.83
# 75%        58.70
# max        66.93
# Name: DXXT8_DXXPOSTH, dtype: float64
#
# Coluna: OHQ_OHQ033
# Total de valores imputados: 5050
# Valores imputados na classe 0: 4013
# Valores imputados na classe 1: 1037
# Porcentagem na classe 1: 20.53%
#
# Estatísticas dos valores:
# Originais:
# count    2874.00
# mean        2.23
# std         1.33
# min         1.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max         9.00
# Name: OHQ_OHQ033, dtype: float64
#
# Imputados:
# count    5050.00
# mean        2.24
# std         0.79
# min         1.00
# 25%         1.67
# 50%         2.33
# 75%         2.67
# max         6.00
# Name: OHQ_OHQ033, dtype: float64
#
# Coluna: OHXPER_OHX04LAD
# Total de valores imputados: 3002
# Valores imputados na classe 0: 2374
# Valores imputados na classe 1: 628
# Porcentagem na classe 1: 20.92%
#
# Estatísticas dos valores:
# Originais:
# count    4922.00
# mean       38.87
# std        46.07
# min         0.00
# 25%         1.00
# 50%         3.00
# 75%        99.00
# max        99.00
# Name: OHXPER_OHX04LAD, dtype: float64
#
# Imputados:
# count    3002.00
# mean       57.67
# std        29.82
# min         1.00
# 25%        34.67
# 50%        66.67
# 75%        67.67
# max        99.00
# Name: OHXPER_OHX04LAD, dtype: float64
#
# Coluna: DR2TOT_DR2DRSTZ
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        1.49
# std         1.31
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         1.00
# max         5.00
# Name: DR2TOT_DR2DRSTZ, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: DR2TOT_DR2DRSTZ, dtype: float64
#
# Coluna: T_score_fn
# Total de valores imputados: 199
# Valores imputados na classe 0: 176
# Valores imputados na classe 1: 23
# Porcentagem na classe 1: 11.56%
#
# Estatísticas dos valores:
# Originais:
# count    7725.00
# mean       -1.13
# std         1.01
# min        -4.63
# 25%        -1.84
# 50%        -1.19
# 75%        -0.50
# max         3.28
# Name: T_score_fn, dtype: float64
#
# Imputados:
# count    199.00
# mean      -0.94
# std        0.57
# min       -2.37
# 25%       -1.36
# 50%       -0.81
# 75%       -0.47
# max        0.37
# Name: T_score_fn, dtype: float64
#
# Coluna: T_score_tf
# Total de valores imputados: 199
# Valores imputados na classe 0: 176
# Valores imputados na classe 1: 23
# Porcentagem na classe 1: 11.56%
#
# Estatísticas dos valores:
# Originais:
# count    7725.00
# mean       -0.70
# std         1.12
# min        -5.15
# 25%        -1.45
# 50%        -0.72
# 75%         0.03
# max         3.45
# Name: T_score_tf, dtype: float64
#
# Imputados:
# count    199.00
# mean      -0.65
# std        0.85
# min       -2.74
# 25%       -1.27
# 50%       -0.63
# 75%        0.06
# max        1.02
# Name: T_score_tf, dtype: float64
#
# Coluna: T_score_sp
# Total de valores imputados: 1758
# Valores imputados na classe 0: 1354
# Valores imputados na classe 1: 404
# Porcentagem na classe 1: 22.98%
#
# Estatísticas dos valores:
# Originais:
# count    6166.00
# mean       -0.45
# std         1.39
# min        -5.45
# 25%        -1.39
# 50%        -0.46
# 75%         0.42
# max         7.24
# Name: T_score_sp, dtype: float64
#
# Imputados:
# count    1758.00
# mean       -0.52
# std         0.92
# min        -2.92
# 25%        -1.05
# 50%        -0.49
# 75%         0.17
# max         1.67
# Name: T_score_sp, dtype: float64
#
# Coluna: BMI
# Total de valores imputados: 31
# Valores imputados na classe 0: 23
# Valores imputados na classe 1: 8
# Porcentagem na classe 1: 25.81%
#
# Estatísticas dos valores:
# Originais:
# count    7893.00
# mean        0.00
# std         0.00
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         0.01
# Name: BMI, dtype: float64
#
# Imputados:
# count    31.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: BMI, dtype: float64
#
# Coluna: BMI_percentil
# Total de valores imputados: 31
# Valores imputados na classe 0: 23
# Valores imputados na classe 1: 8
# Porcentagem na classe 1: 25.81%
#
# Estatísticas dos valores:
# Originais:
# count    7893.00
# mean        7.00
# std         4.32
# min         0.00
# 25%         3.00
# 50%         7.00
# 75%        11.00
# max        14.00
# Name: BMI_percentil, dtype: float64
#
# Imputados:
# count    31.00
# mean      7.15
# std       4.32
# min       0.67
# 25%       3.33
# 50%       6.33
# 75%      11.17
# max      13.67
# Name: BMI_percentil, dtype: float64
#
# Coluna: RIDAGEYR_percentil
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        6.76
# std         4.26
# min         0.00
# 25%         3.00
# 50%         7.00
# 75%        11.00
# max        13.00
# Name: RIDAGEYR_percentil, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: RIDAGEYR_percentil, dtype: float64
#
# Coluna: BMXWT_percentil
# Total de valores imputados: 25
# Valores imputados na classe 0: 19
# Valores imputados na classe 1: 6
# Porcentagem na classe 1: 24.00%
#
# Estatísticas dos valores:
# Originais:
# count    7899.00
# mean        6.99
# std         4.32
# min         0.00
# 25%         3.00
# 50%         7.00
# 75%        11.00
# max        14.00
# Name: BMXWT_percentil, dtype: float64
#
# Imputados:
# count    25.00
# mean      7.52
# std       4.52
# min       0.00
# 25%       3.33
# 50%       8.00
# 75%      11.67
# max      14.00
# Name: BMXWT_percentil, dtype: float64
#
# Coluna: BMXHT_percentil
# Total de valores imputados: 24
# Valores imputados na classe 0: 18
# Valores imputados na classe 1: 6
# Porcentagem na classe 1: 25.00%
#
# Estatísticas dos valores:
# Originais:
# count    7900.00
# mean        6.97
# std         4.32
# min         0.00
# 25%         3.00
# 50%         7.00
# 75%        11.00
# max        14.00
# Name: BMXHT_percentil, dtype: float64
#
# Imputados:
# count    24.00
# mean      7.08
# std       2.89
# min       2.67
# 25%       4.83
# 50%       6.17
# 75%      10.00
# max      12.67
# Name: BMXHT_percentil, dtype: float64
#
# Coluna: BMXARMC_percentil
# Total de valores imputados: 38
# Valores imputados na classe 0: 28
# Valores imputados na classe 1: 10
# Porcentagem na classe 1: 26.32%
#
# Estatísticas dos valores:
# Originais:
# count    7886.00
# mean        6.95
# std         4.33
# min         0.00
# 25%         3.00
# 50%         7.00
# 75%        11.00
# max        14.00
# Name: BMXARMC_percentil, dtype: float64
#
# Imputados:
# count    38.00
# mean      6.56
# std       4.33
# min       0.33
# 25%       2.67
# 50%       6.17
# 75%      10.33
# max      13.33
# Name: BMXARMC_percentil, dtype: float64
#
# Coluna: target
# Total de valores imputados: 0
# Valores imputados na classe 0: 0
# Valores imputados na classe 1: 0
# Porcentagem na classe 1: 0.00%
#
# Estatísticas dos valores:
# Originais:
# count    7924.00
# mean        0.21
# std         0.40
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00
# Name: target, dtype: float64
#
# Imputados:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: target, dtype: float64
#
# Imputação concluída com sucesso!
#
# Processamento concluído com sucesso!
# Shape final do DataFrame: (7924, 208)
#
# Distribuição final da variável target:
# target
# 0.0    79.4
# 1.0    20.6
# Name: proportion, dtype: float64
#
# DataFrame final salvo em: /Users/filipecarvalho/Documents/data_science_projects/BMD/paper/Computers_in_Biology_and_Medicine/NHANES/nhanes_combined_processed.csv

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.base import BaseEstimator, ClassifierMixin

class StackingEnsembleCV(BaseEstimator, ClassifierMixin):
    def __init__(self, n_features=40, n_folds=5):
        self.n_folds = n_folds
        # Base models (first level)
        self.base_models = [
            ('gb', GradientBoostingClassifier(
                n_estimators=170,
                learning_rate=0.15,
                random_state=42,
                min_samples_split=5,
                min_samples_leaf=5
            )),
            ('rf', RandomForestClassifier(
                n_estimators=200,
                max_depth=10,
                min_samples_split=4,
                min_samples_leaf=4,
                random_state=42
            )),
            ('xgb', XGBClassifier(
                n_estimators=150,
                learning_rate=0.12,
                max_depth=6,
                random_state=42,
                eval_metric='logloss'
            )),
            ('lgbm', LGBMClassifier(
                n_estimators=150,
                learning_rate=0.12,
                max_depth=6,
                random_state=42
            ))
        ]
        
        # Meta-model (second level)
        self.meta_model = LogisticRegression(C=0.5, max_iter=800, penalty='l2', random_state=42)
        self.n_features = n_features
        self.classes_ = np.array([0, 1])
        
    def fit(self, X, y):
        self.classes_ = np.unique(y)
        
        # Initialize cross-validation
        kf = KFold(n_splits=self.n_folds, shuffle=True, random_state=42)
        
        # Initialize array for meta features
        meta_features = np.zeros((X.shape[0], len(self.base_models)))
        
        # For each base model
        for i, (name, model) in enumerate(self.base_models):
            # For each fold
            for train_idx, val_idx in kf.split(X):
                X_train_fold, X_val_fold = X.iloc[train_idx], X.iloc[val_idx]
                y_train_fold, y_val_fold = y.iloc[train_idx], y.iloc[val_idx]
                
                # Apply SMOTE only to training fold
                smote = SMOTE(random_state=42)
                X_train_resampled, y_train_resampled = smote.fit_resample(X_train_fold, y_train_fold)
                
                # Train model on the fold
                weights = np.where(y_train_resampled == 1, 5, 1)
                model.fit(X_train_resampled, y_train_resampled,
                         sample_weight=weights if name in ['gb', 'rf'] else None)
                
                # Generate predictions for validation fold
                meta_features[val_idx, i] = model.predict_proba(X_val_fold)[:, 1]
        
        # Train meta-model on the full meta-features
        self.meta_model.fit(meta_features, y)
        
        # Store base models trained on full dataset
        self.final_base_models = []
        for name, model in self.base_models:
            self.final_base_models.append((name, model))
        
        return self
    
    def predict_proba(self, X):
        meta_features = self.get_meta_features(X)
        return self.meta_model.predict_proba(meta_features)
    
    def predict(self, X):
        return self.meta_model.predict(self.get_meta_features(X))
    
    def get_meta_features(self, X):
        meta_features = np.zeros((X.shape[0], len(self.base_models)))
        for i, (name, model) in enumerate(self.base_models):
            meta_features[:, i] = model.predict_proba(X)[:, 1]
        return meta_features
    
    def decision_function(self, X):
        """Required for ROC AUC scoring"""
        return self.predict_proba(X)[:, 1]

def train_stacking_model_cv(df, target_cols, n_folds=5):
    """
    Train the stacking ensemble model with cross-validation.
    """
    # First split into train and test to have a true holdout set
    train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
    
    # Encode categorical variables
    le = LabelEncoder()
    categorical_columns = train_df.select_dtypes(include=['object']).columns
    
    # Fit encoder on training data only
    train_encoded = train_df.copy()
    test_encoded = test_df.copy()
    
    for column in categorical_columns:
        le = LabelEncoder()
        train_encoded[column] = le.fit_transform(train_encoded[column].astype(str))
        # Transform test data with training encoders
        test_encoded[column] = le.transform(test_encoded[column].astype(str))

    # Prepare features and target
    X_train = train_encoded.drop(columns=target_cols, errors='ignore')
    y_train = train_encoded['target'].astype(int)
    X_test = test_encoded.drop(columns=target_cols, errors='ignore')
    y_test = test_encoded['target'].astype(int)

    # Initialize cross-validation
    cv = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    
    # Initialize and train stacking ensemble
    stacking = StackingEnsembleCV(n_folds=n_folds)
    
    # Perform cross-validation on training data
    cv_scores = cross_val_score(stacking, X_train, y_train, cv=cv, scoring='roc_auc')
    
    # Train final model on full training dataset
    stacking.fit(X_train, y_train)
    
    # Generate predictions for the test dataset
    predictions = stacking.predict(X_test)
    probabilities = stacking.predict_proba(X_test)[:, 1]

    # Generate evaluation metrics
    results = {
        'model': stacking,
        'cv_scores': cv_scores,
        'cv_mean_score': np.mean(cv_scores),
        'cv_std_score': np.std(cv_scores),
        'confusion_matrix': confusion_matrix(y_test, predictions),
        'classification_report': classification_report(y_test, predictions),
        'roc_auc': roc_auc_score(y_test, probabilities),
        'predictions': predictions,
        'probabilities': probabilities,
        'y_true': y_test
    }

    return results

# Example usage
target_columns = ["target", "BMI_percentil", "T_score_fn", "RIDAGEYR_percentil",
                 "BMXWT_percentil", "BMXHT_percentil", "BMXARMC_percentil",
                 "T_score_tf", "DXXT8_DXXPOSTH", "DXXT4_DXXANTEH", "DXXT7_DXXPT16Y",
                 "DXXFEM_DXAFMRD0", "T_score_sp", "DXXSPN_DXXOSBMD",
                 "DXXFEM_DXAFMRD0", "DXXFEM_DXXNKBMD", "DXXFEM_DXXOFBMD"]

results_stacking_cv = train_stacking_model_cv(df_final, target_columns, n_folds=5)

print("\nCross-validation scores:")
for i, score in enumerate(results_stacking_cv['cv_scores'], 1):
    print(f"Fold {i}: {score:.4f}")
print(f"\nMean CV Score: {results_stacking_cv['cv_mean_score']:.4f} (+/- {results_stacking_cv['cv_std_score']*2:.4f})")
print("\nFinal Model Classification Report:")
print(results_stacking_cv['classification_report'])
print(f"\nFinal Model ROC AUC Score: {results_stacking_cv['roc_auc']:.4f}")
# Out:
# Cross-validation scores:
# Fold 1: 0.9461
# Fold 2: 0.9365
# Fold 3: 0.9271
# Fold 4: 0.9016
# Fold 5: 0.9322
#
# Mean CV Score: 0.9287 (+/- 0.0298)
#
# Final Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1258
#            1       0.90      0.72      0.80       327
#
#     accuracy                           0.93      1585
#    macro avg       0.92      0.85      0.88      1585
# weighted avg       0.92      0.93      0.92      1585
#
#
# Final Model ROC AUC Score: 0.9377

# %%
# save_model.py
import joblib
from pathlib import Path

def save_trained_model(model, output_dir="models"):
    """
    Salva o modelo treinado e seus componentes
    """
    # Criar diretório se não existir
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Salvar o modelo completo
    model_path = Path(output_dir) / "stacking_ensemble_model.joblib"
    joblib.dump(model, model_path)
    print(f"Modelo salvo em: {model_path}")

# Uso
if __name__ == "__main__":
    # Assumindo que results_stacking_cv é o resultado do seu treinamento
    model = results_stacking_cv['model']
    save_trained_model(model)
